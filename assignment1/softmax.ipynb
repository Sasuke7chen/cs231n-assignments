# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = None
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.356895
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *When W is nearly a zero matrix, the loss equals to $-log(\frac{1}{C})$. The number of the classes is 10 here, which means the C in the loss function equals to 10, and the loss comes to be $-log(\frac{1}{10})=-log(0.1)$*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.233692 analytic: 0.233692, relative error: 9.952152e-08
# numerical: 2.585036 analytic: 2.585036, relative error: 2.614011e-08
# numerical: 1.807529 analytic: 1.807529, relative error: 9.929626e-09
# numerical: 1.021436 analytic: 1.021436, relative error: 8.703195e-08
# numerical: -0.529795 analytic: -0.529795, relative error: 4.980070e-08
# numerical: 1.337597 analytic: 1.337597, relative error: 9.358793e-09
# numerical: -1.249703 analytic: -1.249703, relative error: 6.647542e-08
# numerical: 1.633662 analytic: 1.633662, relative error: 4.946902e-08
# numerical: 0.033307 analytic: 0.033307, relative error: 1.119517e-06
# numerical: 0.348168 analytic: 0.348168, relative error: 3.372709e-08
# numerical: -0.580462 analytic: -0.580462, relative error: 6.250644e-08
# numerical: -3.080355 analytic: -3.080355, relative error: 4.450711e-09
# numerical: 1.773970 analytic: 1.773970, relative error: 2.842088e-08
# numerical: 1.428369 analytic: 1.428369, relative error: 1.560380e-08
# numerical: -1.533511 analytic: -1.533511, relative error: 2.354100e-08
# numerical: 1.571046 analytic: 1.571046, relative error: 5.173188e-08
# numerical: -5.891827 analytic: -5.891827, relative error: 6.563088e-09
# numerical: 2.628409 analytic: 2.628409, relative error: 6.053359e-09
# numerical: -3.928637 analytic: -3.928637, relative error: 1.533851e-08
# numerical: 0.405220 analytic: 0.405220, relative error: 1.339196e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.356895e+00 computed in 0.059298s
# vectorized loss: 2.356895e+00 computed in 0.001945s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = np.linspace(5e-8, 5e-7, num=5)
regularization_strengths = np.linspace(2e4, 3e4, num=5)

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_acc = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_acc = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = train_acc, val_acc
        if val_acc > best_val:
            best_softmax = softmax
            best_val = val_acc

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 628.851612
# iteration 100 / 1500: loss 420.973553
# iteration 200 / 1500: loss 281.980607
# iteration 300 / 1500: loss 189.464677
# iteration 400 / 1500: loss 127.409524
# iteration 500 / 1500: loss 85.925750
# iteration 600 / 1500: loss 58.109753
# iteration 700 / 1500: loss 39.566210
# iteration 800 / 1500: loss 27.214045
# iteration 900 / 1500: loss 18.944881
# iteration 1000 / 1500: loss 13.281398
# iteration 1100 / 1500: loss 9.551973
# iteration 1200 / 1500: loss 7.086034
# iteration 1300 / 1500: loss 5.457541
# iteration 1400 / 1500: loss 4.346730
# iteration 0 / 1500: loss 687.719245
# iteration 100 / 1500: loss 437.917976
# iteration 200 / 1500: loss 279.430232
# iteration 300 / 1500: loss 178.484141
# iteration 400 / 1500: loss 114.463308
# iteration 500 / 1500: loss 73.456221
# iteration 600 / 1500: loss 47.541260
# iteration 700 / 1500: loss 31.052826
# iteration 800 / 1500: loss 20.485554
# iteration 900 / 1500: loss 13.743961
# iteration 1000 / 1500: loss 9.521926
# iteration 1100 / 1500: loss 6.798585
# iteration 1200 / 1500: loss 5.119458
# iteration 1300 / 1500: loss 3.948850
# iteration 1400 / 1500: loss 3.354925
# iteration 0 / 1500: loss 766.783383
# iteration 100 / 1500: loss 464.006772
# iteration 200 / 1500: loss 281.398191
# iteration 300 / 1500: loss 171.095823
# iteration 400 / 1500: loss 104.313548
# iteration 500 / 1500: loss 63.993827
# iteration 600 / 1500: loss 39.611284
# iteration 700 / 1500: loss 24.865945
# iteration 800 / 1500: loss 15.888872
# iteration 900 / 1500: loss 10.418739
# iteration 1000 / 1500: loss 7.133532
# iteration 1100 / 1500: loss 5.082371
# iteration 1200 / 1500: loss 3.944617
# iteration 1300 / 1500: loss 3.181617
# iteration 1400 / 1500: loss 2.794164
# iteration 0 / 1500: loss 854.244674
# iteration 100 / 1500: loss 491.638633
# iteration 200 / 1500: loss 283.831960
# iteration 300 / 1500: loss 164.229484
# iteration 400 / 1500: loss 95.501715
# iteration 500 / 1500: loss 55.826256
# iteration 600 / 1500: loss 33.036363
# iteration 700 / 1500: loss 19.945625
# iteration 800 / 1500: loss 12.380846
# iteration 900 / 1500: loss 8.103814
# iteration 1000 / 1500: loss 5.416440
# iteration 1100 / 1500: loss 4.084856
# iteration 1200 / 1500: loss 3.192695
# iteration 1300 / 1500: loss 2.716321
# iteration 1400 / 1500: loss 2.478102
# iteration 0 / 1500: loss 934.880078
# iteration 100 / 1500: loss 512.670455
# iteration 200 / 1500: loss 281.613406
# iteration 300 / 1500: loss 155.009401
# iteration 400 / 1500: loss 85.825322
# iteration 500 / 1500: loss 47.997371
# iteration 600 / 1500: loss 27.227147
# iteration 700 / 1500: loss 15.845024
# iteration 800 / 1500: loss 9.604896
# iteration 900 / 1500: loss 6.207616
# iteration 1000 / 1500: loss 4.329972
# iteration 1100 / 1500: loss 3.422037
# iteration 1200 / 1500: loss 2.788052
# iteration 1300 / 1500: loss 2.475117
# iteration 1400 / 1500: loss 2.273271
# iteration 0 / 1500: loss 619.010457
# iteration 100 / 1500: loss 167.994568
# iteration 200 / 1500: loss 46.941711
# iteration 300 / 1500: loss 14.270009
# iteration 400 / 1500: loss 5.293115
# iteration 500 / 1500: loss 2.958598
# iteration 600 / 1500: loss 2.274318
# iteration 700 / 1500: loss 2.126458
# iteration 800 / 1500: loss 2.090046
# iteration 900 / 1500: loss 2.077397
# iteration 1000 / 1500: loss 2.117610
# iteration 1100 / 1500: loss 2.072045
# iteration 1200 / 1500: loss 2.067468
# iteration 1300 / 1500: loss 2.066131
# iteration 1400 / 1500: loss 2.022747
# iteration 0 / 1500: loss 700.734711
# iteration 100 / 1500: loss 161.804054
# iteration 200 / 1500: loss 38.703047
# iteration 300 / 1500: loss 10.508623
# iteration 400 / 1500: loss 4.022317
# iteration 500 / 1500: loss 2.533683
# iteration 600 / 1500: loss 2.181875
# iteration 700 / 1500: loss 2.058591
# iteration 800 / 1500: loss 2.070077
# iteration 900 / 1500: loss 2.073466
# iteration 1000 / 1500: loss 2.060775
# iteration 1100 / 1500: loss 2.066979
# iteration 1200 / 1500: loss 2.057498
# iteration 1300 / 1500: loss 2.056797
# iteration 1400 / 1500: loss 2.139438
# iteration 0 / 1500: loss 774.641466
# iteration 100 / 1500: loss 152.197625
# iteration 200 / 1500: loss 31.386420
# iteration 300 / 1500: loss 7.769894
# iteration 400 / 1500: loss 3.238060
# iteration 500 / 1500: loss 2.267063
# iteration 600 / 1500: loss 2.202208
# iteration 700 / 1500: loss 2.071588
# iteration 800 / 1500: loss 2.086299
# iteration 900 / 1500: loss 2.061146
# iteration 1000 / 1500: loss 2.086258
# iteration 1100 / 1500: loss 2.063020
# iteration 1200 / 1500: loss 2.035742
# iteration 1300 / 1500: loss 2.070116
# iteration 1400 / 1500: loss 2.057497
# iteration 0 / 1500: loss 848.818321
# iteration 100 / 1500: loss 141.617772
# iteration 200 / 1500: loss 25.223542
# iteration 300 / 1500: loss 5.925486
# iteration 400 / 1500: loss 2.710819
# iteration 500 / 1500: loss 2.225732
# iteration 600 / 1500: loss 2.095431
# iteration 700 / 1500: loss 2.061758
# iteration 800 / 1500: loss 2.104434
# iteration 900 / 1500: loss 2.083007
# iteration 1000 / 1500: loss 2.134682
# iteration 1100 / 1500: loss 2.118377
# iteration 1200 / 1500: loss 2.052706
# iteration 1300 / 1500: loss 2.141683
# iteration 1400 / 1500: loss 2.048946
# iteration 0 / 1500: loss 939.426340
# iteration 100 / 1500: loss 133.599100
# iteration 200 / 1500: loss 20.534765
# iteration 300 / 1500: loss 4.677470
# iteration 400 / 1500: loss 2.433651
# iteration 500 / 1500: loss 2.086749
# iteration 600 / 1500: loss 2.065138
# iteration 700 / 1500: loss 2.131651
# iteration 800 / 1500: loss 2.108858
# iteration 900 / 1500: loss 2.092539
# iteration 1000 / 1500: loss 2.119952
# iteration 1100 / 1500: loss 2.093873
# iteration 1200 / 1500: loss 2.125585
# iteration 1300 / 1500: loss 2.103206
# iteration 1400 / 1500: loss 2.073185
# iteration 0 / 1500: loss 621.457818
# iteration 100 / 1500: loss 69.083626
# iteration 200 / 1500: loss 9.306992
# iteration 300 / 1500: loss 2.869034
# iteration 400 / 1500: loss 2.220625
# iteration 500 / 1500: loss 2.121932
# iteration 600 / 1500: loss 2.105636
# iteration 700 / 1500: loss 2.086364
# iteration 800 / 1500: loss 2.057950
# iteration 900 / 1500: loss 2.061716
# iteration 1000 / 1500: loss 2.105766
# iteration 1100 / 1500: loss 2.080022
# iteration 1200 / 1500: loss 2.010110
# iteration 1300 / 1500: loss 2.044545
# iteration 1400 / 1500: loss 2.151334
# iteration 0 / 1500: loss 685.560248
# iteration 100 / 1500: loss 58.243241
# iteration 200 / 1500: loss 6.766718
# iteration 300 / 1500: loss 2.497829
# iteration 400 / 1500: loss 2.104761
# iteration 500 / 1500: loss 2.076714
# iteration 600 / 1500: loss 2.106309
# iteration 700 / 1500: loss 2.088621
# iteration 800 / 1500: loss 2.059993
# iteration 900 / 1500: loss 2.061590
# iteration 1000 / 1500: loss 2.004267
# iteration 1100 / 1500: loss 2.084125
# iteration 1200 / 1500: loss 2.105402
# iteration 1300 / 1500: loss 2.033325
# iteration 1400 / 1500: loss 2.080618
# iteration 0 / 1500: loss 764.031190
# iteration 100 / 1500: loss 49.357525
# iteration 200 / 1500: loss 5.066742
# iteration 300 / 1500: loss 2.277124
# iteration 400 / 1500: loss 2.025508
# iteration 500 / 1500: loss 2.075935
# iteration 600 / 1500: loss 2.085154
# iteration 700 / 1500: loss 2.099026
# iteration 800 / 1500: loss 2.066872
# iteration 900 / 1500: loss 2.054824
# iteration 1000 / 1500: loss 2.130294
# iteration 1100 / 1500: loss 2.058907
# iteration 1200 / 1500: loss 2.115840
# iteration 1300 / 1500: loss 2.112579
# iteration 1400 / 1500: loss 2.054018
# iteration 0 / 1500: loss 850.649856
# iteration 100 / 1500: loss 42.001855
# iteration 200 / 1500: loss 4.000106
# iteration 300 / 1500: loss 2.190147
# iteration 400 / 1500: loss 2.118620
# iteration 500 / 1500: loss 2.059253
# iteration 600 / 1500: loss 2.043400
# iteration 700 / 1500: loss 2.016293
# iteration 800 / 1500: loss 2.056133
# iteration 900 / 1500: loss 2.093974
# iteration 1000 / 1500: loss 2.106391
# iteration 1100 / 1500: loss 2.111181
# iteration 1200 / 1500: loss 2.093493
# iteration 1300 / 1500: loss 2.060655
# iteration 1400 / 1500: loss 2.110942
# iteration 0 / 1500: loss 919.604254
# iteration 100 / 1500: loss 34.696871
# iteration 200 / 1500: loss 3.205278
# iteration 300 / 1500: loss 2.111932
# iteration 400 / 1500: loss 2.082446
# iteration 500 / 1500: loss 2.125144
# iteration 600 / 1500: loss 2.107670
# iteration 700 / 1500: loss 2.086427
# iteration 800 / 1500: loss 2.124912
# iteration 900 / 1500: loss 2.076841
# iteration 1000 / 1500: loss 2.147864
# iteration 1100 / 1500: loss 2.112419
# iteration 1200 / 1500: loss 2.130345
# iteration 1300 / 1500: loss 2.109035
# iteration 1400 / 1500: loss 2.072732
# iteration 0 / 1500: loss 628.918455
# iteration 100 / 1500: loss 29.194545
# iteration 200 / 1500: loss 3.236396
# iteration 300 / 1500: loss 2.096993
# iteration 400 / 1500: loss 2.137005
# iteration 500 / 1500: loss 2.138611
# iteration 600 / 1500: loss 2.041642
# iteration 700 / 1500: loss 2.047341
# iteration 800 / 1500: loss 2.084701
# iteration 900 / 1500: loss 2.007035
# iteration 1000 / 1500: loss 2.003796
# iteration 1100 / 1500: loss 2.152315
# iteration 1200 / 1500: loss 2.063524
# iteration 1300 / 1500: loss 2.075471
# iteration 1400 / 1500: loss 2.083771
# iteration 0 / 1500: loss 698.546720
# iteration 100 / 1500: loss 22.497160
# iteration 200 / 1500: loss 2.613221
# iteration 300 / 1500: loss 2.066816
# iteration 400 / 1500: loss 2.073331
# iteration 500 / 1500: loss 2.084817
# iteration 600 / 1500: loss 2.078763
# iteration 700 / 1500: loss 2.119527
# iteration 800 / 1500: loss 2.038190
# iteration 900 / 1500: loss 2.005125
# iteration 1000 / 1500: loss 2.090273
# iteration 1100 / 1500: loss 2.123031
# iteration 1200 / 1500: loss 2.151184
# iteration 1300 / 1500: loss 2.124574
# iteration 1400 / 1500: loss 2.008853
# iteration 0 / 1500: loss 768.005387
# iteration 100 / 1500: loss 17.190253
# iteration 200 / 1500: loss 2.428541
# iteration 300 / 1500: loss 2.101979
# iteration 400 / 1500: loss 2.016228
# iteration 500 / 1500: loss 2.123392
# iteration 600 / 1500: loss 2.051708
# iteration 700 / 1500: loss 2.123616
# iteration 800 / 1500: loss 2.105392
# iteration 900 / 1500: loss 2.123457
# iteration 1000 / 1500: loss 2.090260
# iteration 1100 / 1500: loss 2.105101
# iteration 1200 / 1500: loss 2.051777
# iteration 1300 / 1500: loss 2.069904
# iteration 1400 / 1500: loss 2.114773
# iteration 0 / 1500: loss 847.268308
# iteration 100 / 1500: loss 13.278083
# iteration 200 / 1500: loss 2.224815
# iteration 300 / 1500: loss 2.095309
# iteration 400 / 1500: loss 2.095375
# iteration 500 / 1500: loss 2.107888
# iteration 600 / 1500: loss 2.130761
# iteration 700 / 1500: loss 2.182714
# iteration 800 / 1500: loss 2.090369
# iteration 900 / 1500: loss 2.039851
# iteration 1000 / 1500: loss 2.125462
# iteration 1100 / 1500: loss 2.105291
# iteration 1200 / 1500: loss 2.070429
# iteration 1300 / 1500: loss 2.125489
# iteration 1400 / 1500: loss 2.141610
# iteration 0 / 1500: loss 922.519656
# iteration 100 / 1500: loss 10.314303
# iteration 200 / 1500: loss 2.231395
# iteration 300 / 1500: loss 2.064634
# iteration 400 / 1500: loss 2.077940
# iteration 500 / 1500: loss 2.090403
# iteration 600 / 1500: loss 2.146030
# iteration 700 / 1500: loss 2.128895
# iteration 800 / 1500: loss 2.137532
# iteration 900 / 1500: loss 2.083722
# iteration 1000 / 1500: loss 2.113869
# iteration 1100 / 1500: loss 2.147684
# iteration 1200 / 1500: loss 2.147928
# iteration 1300 / 1500: loss 2.096388
# iteration 1400 / 1500: loss 2.020005
# iteration 0 / 1500: loss 616.497656
# iteration 100 / 1500: loss 12.692248
# iteration 200 / 1500: loss 2.279960
# iteration 300 / 1500: loss 2.054094
# iteration 400 / 1500: loss 2.063931
# iteration 500 / 1500: loss 2.137741
# iteration 600 / 1500: loss 2.063520
# iteration 700 / 1500: loss 2.053079
# iteration 800 / 1500: loss 2.046613
# iteration 900 / 1500: loss 2.044108
# iteration 1000 / 1500: loss 2.107927
# iteration 1100 / 1500: loss 2.078238
# iteration 1200 / 1500: loss 2.059821
# iteration 1300 / 1500: loss 2.054059
# iteration 1400 / 1500: loss 2.052016
# iteration 0 / 1500: loss 704.271343
# iteration 100 / 1500: loss 9.275059
# iteration 200 / 1500: loss 2.205891
# iteration 300 / 1500: loss 2.104143
# iteration 400 / 1500: loss 2.027331
# iteration 500 / 1500: loss 2.137324
# iteration 600 / 1500: loss 2.081456
# iteration 700 / 1500: loss 2.128770
# iteration 800 / 1500: loss 2.059868
# iteration 900 / 1500: loss 2.081248
# iteration 1000 / 1500: loss 2.057431
# iteration 1100 / 1500: loss 2.150967
# iteration 1200 / 1500: loss 2.131769
# iteration 1300 / 1500: loss 2.085977
# iteration 1400 / 1500: loss 2.082274
# iteration 0 / 1500: loss 769.272804
# iteration 100 / 1500: loss 6.897270
# iteration 200 / 1500: loss 2.133112
# iteration 300 / 1500: loss 2.114422
# iteration 400 / 1500: loss 2.115806
# iteration 500 / 1500: loss 2.068151
# iteration 600 / 1500: loss 2.056941
# iteration 700 / 1500: loss 2.154939
# iteration 800 / 1500: loss 2.116987
# iteration 900 / 1500: loss 2.056954
# iteration 1000 / 1500: loss 2.044304
# iteration 1100 / 1500: loss 2.107947
# iteration 1200 / 1500: loss 2.069048
# iteration 1300 / 1500: loss 2.099604
# iteration 1400 / 1500: loss 2.061129
# iteration 0 / 1500: loss 861.907793
# iteration 100 / 1500: loss 5.304222
# iteration 200 / 1500: loss 2.098237
# iteration 300 / 1500: loss 2.112478
# iteration 400 / 1500: loss 2.079532
# iteration 500 / 1500: loss 2.096741
# iteration 600 / 1500: loss 2.079941
# iteration 700 / 1500: loss 2.072318
# iteration 800 / 1500: loss 2.138663
# iteration 900 / 1500: loss 2.140153
# iteration 1000 / 1500: loss 2.113196
# iteration 1100 / 1500: loss 2.083466
# iteration 1200 / 1500: loss 2.094702
# iteration 1300 / 1500: loss 2.103276
# iteration 1400 / 1500: loss 2.066350
# iteration 0 / 1500: loss 930.779703
# iteration 100 / 1500: loss 4.169032
# iteration 200 / 1500: loss 2.142734
# iteration 300 / 1500: loss 2.101259
# iteration 400 / 1500: loss 2.040335
# iteration 500 / 1500: loss 2.056667
# iteration 600 / 1500: loss 2.132173
# iteration 700 / 1500: loss 2.090564
# iteration 800 / 1500: loss 2.107008
# iteration 900 / 1500: loss 2.149107
# iteration 1000 / 1500: loss 2.099197
# iteration 1100 / 1500: loss 2.169797
# iteration 1200 / 1500: loss 2.090392
# iteration 1300 / 1500: loss 2.081978
# iteration 1400 / 1500: loss 2.136854
# lr 5.000000e-08 reg 2.000000e+04 train accuracy: 0.329959 val accuracy: 0.347000
# lr 5.000000e-08 reg 2.250000e+04 train accuracy: 0.326327 val accuracy: 0.344000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.323429 val accuracy: 0.338000
# lr 5.000000e-08 reg 2.750000e+04 train accuracy: 0.327102 val accuracy: 0.346000
# lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.321510 val accuracy: 0.333000
# lr 1.625000e-07 reg 2.000000e+04 train accuracy: 0.335571 val accuracy: 0.346000
# lr 1.625000e-07 reg 2.250000e+04 train accuracy: 0.328367 val accuracy: 0.348000
# lr 1.625000e-07 reg 2.500000e+04 train accuracy: 0.321102 val accuracy: 0.340000
# lr 1.625000e-07 reg 2.750000e+04 train accuracy: 0.326510 val accuracy: 0.340000
# lr 1.625000e-07 reg 3.000000e+04 train accuracy: 0.327163 val accuracy: 0.335000
# lr 2.750000e-07 reg 2.000000e+04 train accuracy: 0.329755 val accuracy: 0.350000
# lr 2.750000e-07 reg 2.250000e+04 train accuracy: 0.327388 val accuracy: 0.347000
# lr 2.750000e-07 reg 2.500000e+04 train accuracy: 0.321367 val accuracy: 0.351000
# lr 2.750000e-07 reg 2.750000e+04 train accuracy: 0.323000 val accuracy: 0.350000
# lr 2.750000e-07 reg 3.000000e+04 train accuracy: 0.326265 val accuracy: 0.342000
# lr 3.875000e-07 reg 2.000000e+04 train accuracy: 0.338714 val accuracy: 0.357000
# lr 3.875000e-07 reg 2.250000e+04 train accuracy: 0.326796 val accuracy: 0.341000
# lr 3.875000e-07 reg 2.500000e+04 train accuracy: 0.329551 val accuracy: 0.350000
# lr 3.875000e-07 reg 2.750000e+04 train accuracy: 0.310898 val accuracy: 0.330000
# lr 3.875000e-07 reg 3.000000e+04 train accuracy: 0.318714 val accuracy: 0.332000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.330061 val accuracy: 0.344000
# lr 5.000000e-07 reg 2.250000e+04 train accuracy: 0.337551 val accuracy: 0.352000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.322327 val accuracy: 0.342000
# lr 5.000000e-07 reg 2.750000e+04 train accuracy: 0.316061 val accuracy: 0.332000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.324143 val accuracy: 0.347000
# best validation accuracy achieved during cross-validation: 0.357000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.337000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ *True*
#
#
# $\color{blue}{\textit Your Explanation:}$ *In SVM we only care about whether the score of the corret class is larger enough than any score of the other classes. The SVM loss of a datapoint could be zero in the case mentioned above. So it is possible to add a new datapoint to a training set that would leave the SVM loss unchanged. In Softmax classifier, every datapoint has contribution to the loss.*

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
